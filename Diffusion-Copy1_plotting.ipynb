# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']

# %%
## test run with 2D datasets
points = np.random.rand(10, 2)
print(points)

for i in range(10):
    plt.scatter(points[i,0], points[i,1], c=colors[i], marker='|')


std = np.std(points)
mean = np.mean(points)
points_normalized = (points-mean)/std

for i in range(10):
    plt.scatter(points_normalized[i,0], points_normalized[i,1], c=colors[i])
# Out:
# [[0.34447438 0.84008197]
#  [0.75384013 0.90657093]
#  [0.20239707 0.5812015 ]
#  [0.40573538 0.2647697 ]
#  [0.54795706 0.52123325]
#  [0.50715385 0.04431798]
#  [0.85716635 0.67066035]
#  [0.69183885 0.74777514]
#  [0.4883415  0.13035667]
#  [0.1451083  0.96286344]]

# %%
df = pd.read_csv(f'./diffusion logs/08182022_205351.csv', header=None)
print(min(df[0]))
df = df[26000:]
df = df[df<0.005]
df.plot()
plt.show()
# Out:
# 0.0011197245912626

# %%
df = pd.read_csv(f'./diffusion logs/08182022_141035.csv', header=None)
df.plot()
plt.show()

# %%
df = pd.read_csv(f'./diffusion logs/08182022_134617.csv', header=None)
df.plot()
plt.show()

# %%
df = pd.read_csv(f'./diffusion logs/08182022_134617.csv', header=None)
df.plot()
plt.show()

# %%
df = pd.read_csv(f'./diffusion logs/08182022_134617.csv', header=None)
df.plot()
plt.show()
